# %%
#ÖVNINGSUPPGIFT 

import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd 

data = pd.read_csv("National_Daily_Deaths.csv", encoding="ISO-8859-1", header=1)

df = pd.DataFrame(data) 


x = list(df.iloc[:, 0])
y = list(df.iloc[:, 1])

plt.bar(x, y)
plt.title("Graf över antalet döda per dag")
plt.xlabel("datum")
plt.ylabel("antal döda")
plt.show()884567868

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-34ae06cdf050> in <module>
# ----> 1 import plotly.express as px
#       2 import dash
#       3 import dash_core_components as dcc
#       4 import dash_html_components as HTML
#       5 import pandas as pd
#
# ModuleNotFoundError: No module named 'plotly'

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-14-a65cd42216ac> in <module>
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import plotly.express as px
#       4
#       5 kön = pd.read_csv("Gender_Data.csv", encoding="ISO-8859-1", header=1)
#
# ModuleNotFoundError: No module named 'plotly'
